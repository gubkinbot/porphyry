# %% [markdown]
# # Porphyry!

# %% [markdown]
# ## Валидация замеров дебита скважин

# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv('data/dataset.csv', index_col=0, parse_dates=True)
data
# Out:
#                            V1          D1         T4         H1          P5  \
# Timestamp
# 2018-07-31 10:47:00  4.617656  367.348275  36.324918  12.852977   52.725645
# 2018-07-31 10:48:00  3.707020   15.067804  36.298069  12.976562   52.669229
# 2018-07-31 10:49:00  4.234867  177.124920  36.303446  13.094770   52.725645
# 2018-07-31 10:50:00  3.972958  356.677230  36.238997  13.245225   52.612823
# 2018-07-31 10:51:00  4.335601  348.615960  36.308800  13.035666   52.725645
# ...                       ...         ...        ...        ...         ...
# 2021-12-21 16:55:00  8.090973  182.943705  21.018795  33.540245  821.761185
# 2021-12-21 16:56:00  8.977437  188.955900  21.008054  32.949179  821.180955
# 2021-12-21 16:57:00  7.671921  169.894935  21.013430  32.911567  821.277660
# 2021-12-21 16:58:00  9.851810  174.167175  20.997312  32.868581  821.108505
# 2021-12-21 16:59:00  7.796830  191.623635  20.970464  32.787982  821.398515
#
# ...

# %% [markdown]
# **Краткое описание данных:**
#
# * Q1 - целевая функция, дебит;
# * L, D, G, H - индивидуальные параметры скважин и ее шлейфов (одинаковы для всех наблюдений скважины);
# * WELL - номер скважины;
# * DDTS - порядковый номер замера дебита;
# * P1, P2, P3, P4, P5, P6, T1, T2, T3, T4, T5, V1, D1, H1 - признаковое пространство.

# %%
# px.histogram(data, x='P1', color='WELL', height=600)
